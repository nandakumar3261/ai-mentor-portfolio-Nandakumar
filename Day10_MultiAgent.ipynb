# %% [markdown]
# <a href="https://colab.research.google.com/github/nandakumar3261/ai-mentor-portfolio-Nandakumar/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1e6f141d-37ed-431c-9712-5f00f3f24307                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 031110ee-b480-4606-a930-a998a88f32ce                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital placement preparation for B.Tech students:                            │
# │                                                                                                                 │
# │  *   **Hiring Process**                                                                                         │
# │      *   **Online Aptitude Test**: Assesses numerical, verbal, and logical reasoning skills.                    │
# │      *   **Coding Round**: Typically 1-2 medium to hard coding problems, often focusing on Data Structures &    │
# │  Algorithms.                                                                                                    │
# │      *   **Technical Interview**: In-depth discussion on projects, core CS subjects (OS, DBMS, OOPS, CN), and   │
# │  problem-solving approach.                                                                                      │
# │      *   **Managerial Interview (Optional but common)**: Focuses on situational awareness, career goals, and    │
# │  technical leadership potential.                                                                                │
# │      *   **HR Interview**: Evaluates communication skills, cultural fit, and discusses                          │
# │  compensation/relocation.                                                                                       │
# │                                                                                                                 │
# │  *   **Technical Stack**                                                                                        │
# │      *   **Programming Languages**: Strong proficiency in Java, Python, or C++ is crucial.                      │
# │      *   **Data Structures & Algorithms**: Fundamental for problem-solving and coding rounds.                   │
# │      *   **Core CS Concepts**: Operating Systems, Database Management Systems (SQL), Object-Oriented            │
# │  Programming (OOPs).                                                                                            │
# │      *   **Web Technologies**: HTML, CSS, JavaScript, and familiarity with frameworks (e.g., React, Angular)    │
# │  for relevant roles.                                                                                            │
# │      *   **Cloud & Emerging Tech**: Awareness of cloud platforms (AWS, Azure, GCP) and technologies like AI/ML  │
# │  or Blockchain is a plus.                                                                                       │
# │                                                                                                                 │
# │  *   **Eligibility**                                                                                            │
# │      *   **Degree**: B.E./B.Tech from all engineering branches are typically eligible.                          │
# │      *   **Academic Criteria**: Generally requires 60% or 6.0 CGPA throughout 10th, 12th, and graduation.       │
# │      *   **Year of Passing**: Open to final year B.Tech students.                                               │
# │      *   **Backlogs/Gaps**: No active backlogs; maximum 1-year gap in education with valid reasons.             │
# │                                                                                                                 │
# │  *   **Recent Hiring Trends**                                                                                   │
# │      *   **Increased Difficulty in Coding**: Digital role's coding round is significantly tougher than Ninja,   │
# │  demanding strong DSA.                                                                                          │
# │      *   **Focus on Project Work**: Candidates with practical project experience and hands-on skills are        │
# │  preferred.                                                                                                     │
# │      *   **Demand for Niche Skills**: Growing interest in candidates with exposure to AI/ML, Cloud Computing,   │
# │  Cybersecurity, and IoT.                                                                                        │
# │      *   **Higher Compensation**: TCS Digital offers a significantly higher salary package compared to the      │
# │  Ninja profile.                                                                                                 │
# │      *   **Emphasis on Adaptability**: Hiring candidates who demonstrate continuous learning and ability to     │
# │  quickly grasp new technologies.                                                                                │
# │                                                                                                                 │
# │  *   **Prep Tips**                                                                                              │
# │      *   **Master DSA**: Practice extensively on platforms like LeetCode, HackerRank, GeeksforGeeks for         │
# │  medium-to-hard problems.                                                                                       │
# │      *   **Strengthen CS Fundamentals**: Thoroughly revise OS, DBMS, OOPS, and Computer Networks.               │
# │      *   **Build a Strong Project Portfolio**: Develop impactful projects to showcase practical application of  │
# │  skills.                                                                                                        │
# │      *   **Practice Aptitude & Communication**: Regularly solve quantitative, logical, verbal questions, and    │
# │  improve interview communication.                                                                               │
# │      *   **Stay Updated with Tech**: Follow industry trends and be familiar with emerging technologies          │
# │  relevant to digital transformation.                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 9421bae4-7fc0-4c4f-8dc9-d9c038953d30                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact career at the forefront of technology? TCS Digital offers coveted roles and a        │
# │  premium package for top engineering talent. Prepare strategically to unlock your potential and secure this     │
# │  exciting opportunity!                                                                                          │
# │                                                                                                                 │
# │  ### 1. The Hiring Journey                                                                                      │
# │                                                                                                                 │
# │  Navigate the multi-stage selection process with confidence:                                                    │
# │                                                                                                                 │
# │  *   **Online Aptitude Test**: Sharpen your numerical, verbal, and logical reasoning.                           │
# │  *   **Coding Round**: Expect 1-2 medium-to-hard problems, heavily focused on Data Structures & Algorithms.     │
# │  *   **Technical Interview**: Be ready for in-depth discussions on your projects, core CS subjects (OS, DBMS,   │
# │  OOPS, CN), and problem-solving methodologies.                                                                  │
# │  *   **Managerial Interview (Common)**: Showcase situational awareness, career aspirations, and leadership      │
# │  potential.                                                                                                     │
# │  *   **HR Interview**: Focus on communication skills, cultural fit, and discuss compensation details.           │
# │                                                                                                                 │
# │  ### 2. Your Technical Toolkit                                                                                  │
# │                                                                                                                 │
# │  Master these key areas to stand out:                                                                           │
# │                                                                                                                 │
# │  *   **Programming Languages**: Achieve strong proficiency in Java, Python, or C++.                             │
# │  *   **Data Structures & Algorithms**: Build a rock-solid foundation for efficient problem-solving.             │
# │  *   **Core CS Concepts**: Thoroughly understand Operating Systems, Database Management Systems (SQL), and      │
# │  Object-Oriented Programming (OOPs).                                                                            │
# │  *   **Web Technologies (Relevant Roles)**: Familiarity with HTML, CSS, JavaScript, and frameworks like         │
# │  React/Angular is a plus.                                                                                       │
# │  *   **Cloud & Emerging Tech**: Awareness of AWS, Azure, GCP, AI/ML, or Blockchain demonstrates                 │
# │  forward-thinking.                                                                                              │
# │                                                                                                                 │
# │  ### 3. Are You Eligible?                                                                                       │
# │                                                                                                                 │
# │  Check if you meet the fundamental criteria:                                                                    │
# │                                                                                                                 │
# │  *   **Degree**: All B.E./B.Tech engineering branches are typically eligible.                                   │
# │  *   **Academic Criteria**: Generally requires 60% or 6.0 CGPA throughout 10th, 12th, and graduation.           │
# │  *   **Year of Passing**: Open to final-year B.Tech students.                                                   │
# │  *   **Backlogs/Gaps**: No active backlogs; maximum 1-year education gap with valid justification.              │
# │                                                                                                                 │
# │  ### 4. What's Hot Right Now?                                                                                   │
# │                                                                                                                 │
# │  Understand the current landscape and what TCS Digital values:                                                  │
# │                                                                                                                 │
# │  *   **Increased Coding Difficulty**: The Digital coding round is significantly tougher than Ninja – intense    │
# │  DSA practice is key.                                                                                           │
# │  *   **Focus on Project Work**: Candidates with hands-on, impactful project experience are highly preferred.    │
# │  *   **Demand for Niche Skills**: Exposure to AI/ML, Cloud Computing, Cybersecurity, and IoT offers a distinct  │
# │  advantage.                                                                                                     │
# │  *   **Higher Compensation**: TCS Digital offers a notably higher salary package compared to the Ninja          │
# │  profile.                                                                                                       │
# │  *   **Emphasis on Adaptability**: Showcase a continuous learning mindset and ability to quickly grasp new      │
# │  technologies.                                                                                                  │
# │                                                                                                                 │
# │  ### 5. Your Roadmap to Success                                                                                 │
# │                                                                                                                 │
# │  Follow these actionable tips for effective preparation:                                                        │
# │                                                                                                                 │
# │  *   **Master DSA**: Practice extensively on platforms like LeetCode, HackerRank, and GeeksforGeeks, focusing   │
# │  on medium-to-hard problems.                                                                                    │
# │  *   **Strengthen CS Fundamentals**: Revise OS, DBMS, OOPS, and Computer Networks thoroughly.                   │
# │  *   **Build a Strong Project Portfolio**: Develop practical projects to demonstrate your applied skills and    │
# │  problem-solving abilities.                                                                                     │
# │  *   **Practice Aptitude & Communication**: Regularly solve quantitative, logical, and verbal questions, and    │
# │  refine your interview communication skills.                                                                    │
# │  *   **Stay Updated with Tech**: Follow industry trends and familiarize yourself with emerging technologies     │
# │  relevant to digital transformation.                                                                            │
# │                                                                                                                 │
# │  Success awaits those who prepare diligently and strategically. Start early, stay consistent, and showcase      │
# │  your best to land your dream role. Your journey to a premium tech career begins now!                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career at the forefront of technology? TCS Digital offers coveted roles and a premium package for top engineering talent. Prepare strategically to unlock your potential and secure this exciting opportunity!
#
# ### 1. The Hiring Journey
#
# Navigate the multi-stage selection process with confidence:
#
# *   **Online Aptitude Test**: Sharpen your numerical, verbal, and logical reasoning.
# *   **Coding Round**: Expect 1-2 medium-to-hard problems, heavily focused on Data Structures & Algorithms.
# *   **Technical Interview**: Be ready for in-depth discussions on your projects, core CS subjects (OS, DBMS, OOPS, CN), and problem-solving methodologies.
# *   **Managerial Interview (Common)**: Showcase situational awareness, career aspirations, and leadership potential.
# *   **HR Interview**: Focus on communication skills, cultural fit, and discuss compensation details.
#
# ### 2. Your Technical Toolkit
#
# Master these key areas to stand out:
#
# *   **Programming Languages**: Achieve strong proficiency in Java, Python, or C++.
# *   **Data Structures & Algorithms**: Build a rock-solid foundation for efficient problem-solving.
# *   **Core CS Concepts**: Thoroughly understand Operating Systems, Database Management Systems (SQL), and Object-Oriented Programming (OOPs).
# *   **Web Technologies (Relevant Roles)**: Familiarity with HTML, CSS, JavaScript, and frameworks like React/Angular is a plus.
# *   **Cloud & Emerging Tech**: Awareness of AWS, Azure, GCP, AI/ML, or Blockchain demonstrates forward-thinking.
#
# ### 3. Are You Eligible?
#
# Check if you meet the fundamental criteria:
#
# *   **Degree**: All B.E./B.Tech engineering branches are typically eligible.
# *   **Academic Criteria**: Generally requires 60% or 6.0 CGPA throughout 10th, 12th, and graduation.
# *   **Year of Passing**: Open to final-year B.Tech students.
# *   **Backlogs/Gaps**: No active backlogs; maximum 1-year education gap with valid justification.
#
# ### 4. What's Hot Right Now?
#
# Understand the current landscape and what TCS Digital values:
#
# *   **Increased Coding Difficulty**: The Digital coding round is significantly tougher than Ninja – intense DSA practice is key.
# *   **Focus on Project Work**: Candidates with hands-on, impactful project experience are highly preferred.
# *   **Demand for Niche Skills**: Exposure to AI/ML, Cloud Computing, Cybersecurity, and IoT offers a distinct advantage.
# *   **Higher Compensation**: TCS Digital offers a notably higher salary package compared to the Ninja profile.
# *   **Emphasis on Adaptability**: Showcase a continuous learning mindset and ability to quickly grasp new technologies.
#
# ### 5. Your Roadmap to Success
#
# Follow these actionable tips for effective preparation:
#
# *   **Master DSA**: Practice extensively on platforms like LeetCode, HackerRank, and GeeksforGeeks, focusing on medium-to-hard problems.
# *   **Strengthen CS Fundamentals**: Revise OS, DBMS, OOPS, and Computer Networks thoroughly.
# *   **Build a Strong Project Portfolio**: Develop practical projects to demonstrate your applied skills and problem-solving abilities.
# *   **Practice Aptitude & Communication**: Regularly solve quantitative, logical, and verbal questions, and refine your interview communication skills.
# *   **Stay Updated with Tech**: Follow industry trends and familiarize yourself with emerging technologies relevant to digital transformation.
#
# Success awaits those who prepare diligently and strategically. Start early, stay consistent, and showcase your best to land your dream role. Your journey to a premium tech career begins now!

# %%
await crew.kickoff_async()
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1e6f141d-37ed-431c-9712-5f00f3f24307                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 031110ee-b480-4606-a930-a998a88f32ce                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### TCS Digital Placement Preparation for B.Tech Students                                                      │
# │                                                                                                                 │
# │  **Hiring Process**                                                                                             │
# │  *   **Online Aptitude Test:** Typically begins with a comprehensive test covering quantitative aptitude,       │
# │  verbal ability, and logical reasoning, often integrated with the TCS NQT (National Qualifier Test).            │
# │  *   **Advanced Coding Round:** Candidates who clear the aptitude test proceed to a more challenging coding     │
# │  assessment, featuring multiple problems requiring strong algorithmic and data structure knowledge.             │
# │  *   **Technical Interview:** Focuses on core computer science fundamentals (OS, DBMS, OOPs, CN), projects      │
# │  undertaken, problem-solving approaches, and specific technical skills relevant to digital roles.               │
# │  *   **Managerial & HR Interview:** Evaluates leadership potential, situational problem-solving, project        │
# │  management insights, cultural fit, communication skills, and willingness to learn/relocate.                    │
# │                                                                                                                 │
# │  **Technical Stack**                                                                                            │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental for problem-solving in coding rounds and technical     │
# │  interviews, covering topics like arrays, linked lists, trees, graphs, sorting, and searching.                  │
# │  *   **Cloud Technologies:** Familiarity with concepts and basics of major cloud platforms (AWS, Azure, GCP)    │
# │  is highly valued, especially for digital transformation projects.                                              │
# │  *   **Programming Languages:** Strong proficiency in at least one modern language like Java, Python, C++, or   │
# │  JavaScript, along with understanding of related frameworks (e.g., Spring Boot, Django, Node.js).               │
# │  *   **Emerging Technologies:** Basic understanding of AI/ML concepts, IoT, Blockchain, Big Data, or            │
# │  Cybersecurity principles is beneficial for demonstrating readiness for digital roles.                          │
# │                                                                                                                 │
# │  **Eligibility**                                                                                                │
# │  *   **Academic Percentage:** Generally requires a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and        │
# │  B.Tech/BE degrees.                                                                                             │
# │  *   **Degree and Branches:** B.Tech/BE students from Computer Science, Information Technology, Electronics &   │
# │  Communication, Electrical & Electronics, and related engineering disciplines are typically eligible.           │
# │  *   **No Active Backlogs:** Candidates should ideally not have any active backlogs at the time of applying or  │
# │  during the selection process.                                                                                  │
# │  *   **Gap in Education:** A maximum permissible academic gap of 1-2 years (overall) is usually allowed,        │
# │  depending on the specific hiring drive.                                                                        │
# │                                                                                                                 │
# │  **Recent Hiring Trends**                                                                                       │
# │  *   **Higher Bar for Digital:** TCS Digital roles have a significantly higher cut-off in both aptitude and     │
# │  coding rounds compared to TCS Ninja profiles, demanding top performers.                                        │
# │  *   **Focus on Niche Skills:** Increased emphasis on candidates demonstrating practical knowledge and          │
# │  projects in AI/ML, Data Science, Cloud computing, and advanced web development.                                │
# │  *   **Integrated NQT Process:** Hiring is often conducted through a common NQT gateway, where performance      │
# │  determines eligibility for Digital, Innovator, or Ninja tracks.                                                │
# │  *   **Virtual Assessment & Interviews:** The entire hiring process, from tests to interviews, is               │
# │  predominantly conducted virtually, requiring strong online etiquette and technical setup.                      │
# │                                                                                                                 │
# │  **Prep Tips**                                                                                                  │
# │  *   **Master DSA & Core CS:** Dedicate significant time to practicing Data Structures and Algorithms on        │
# │  platforms like LeetCode and HackerRank, alongside strengthening OS, DBMS, OOPs, and Networking concepts.       │
# │  *   **Build Strong Projects:** Develop 2-3 substantial projects showcasing technical skills in areas like web  │
# │  development (full-stack), machine learning, or cloud integration, rather than just academic assignments.       │
# │  *   **Practice Aptitude Regularly:** Regularly solve quantitative, logical reasoning, and verbal ability       │
# │  questions to improve speed and accuracy for the initial screening test.                                        │
# │  *   **Mock Interviews & Communication:** Engage in mock technical and HR interviews to refine problem-solving  │
# │  articulation, project explanations, and overall communication skills.                                          │
# │  *   **Stay Updated:** Follow industry trends, learn about new technologies, and understand how they are being  │
# │  applied in real-world scenarios, particularly within TCS's digital offerings.                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 9421bae4-7fc0-4c4f-8dc9-d9c038953d30                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Ready to accelerate your career in the cutting-edge world of digital innovation? TCS Digital offers premium    │
# │  roles at the forefront of technology, demanding top talent and a future-forward mindset. This brief is your    │
# │  roadmap to cracking one of India's most sought-after placements.                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Journey                                                                                      │
# │                                                                                                                 │
# │  The TCS Digital selection process is rigorous, designed to identify future tech leaders:                       │
# │                                                                                                                 │
# │  *   **Online Aptitude Test:** A comprehensive screening via TCS NQT (National Qualifier Test), assessing       │
# │  quantitative aptitude, verbal ability, and logical reasoning.                                                  │
# │  *   **Advanced Coding Round:** Clear the aptitude, and you'll face multiple challenging coding problems        │
# │  requiring strong algorithmic and data structure proficiency.                                                   │
# │  *   **Technical Interview:** Deep dive into your core computer science fundamentals (OS, DBMS, OOPs, CN),      │
# │  projects, problem-solving approaches, and relevant technical skills.                                           │
# │  *   **Managerial & HR Interview:** Evaluates leadership potential, situational problem-solving, project        │
# │  insights, cultural fit, communication skills, and adaptability.                                                │
# │                                                                                                                 │
# │  ### 2. Essential Technical Arsenal                                                                             │
# │                                                                                                                 │
# │  TCS Digital roles demand a strong foundation and eagerness to learn emerging tech:                             │
# │                                                                                                                 │
# │  *   **Data Structures & Algorithms (DSA):** Non-negotiable for coding rounds and technical interviews. Master  │
# │  arrays, linked lists, trees, graphs, sorting, searching.                                                       │
# │  *   **Cloud Technologies:** Basic understanding of AWS, Azure, or GCP concepts is highly valued for digital    │
# │  transformation projects.                                                                                       │
# │  *   **Programming Languages:** Strong proficiency in at least one modern language (Java, Python, C++,          │
# │  JavaScript) and familiarity with associated frameworks (e.g., Spring Boot, Django).                            │
# │  *   **Emerging Technologies:** A foundational grasp of AI/ML, IoT, Blockchain, Big Data, or Cybersecurity      │
# │  principles showcases your readiness for digital roles.                                                         │
# │                                                                                                                 │
# │  ### 3. Am I Eligible?                                                                                          │
# │                                                                                                                 │
# │  Ensure you meet the basic criteria before applying:                                                            │
# │                                                                                                                 │
# │  *   **Academic Percentage:** Minimum 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE.                     │
# │  *   **Degree & Branches:** B.Tech/BE from Computer Science, IT, ECE, EEE, and related engineering              │
# │  disciplines.                                                                                                   │
# │  *   **No Active Backlogs:** Must not have any active backlogs at the time of application or during the         │
# │  selection process.                                                                                             │
# │  *   **Academic Gap:** A maximum permissible academic gap of 1-2 years (overall) is generally allowed.          │
# │                                                                                                                 │
# │  ### 4. Key Trends & Expectations                                                                               │
# │                                                                                                                 │
# │  Understand the contemporary landscape of TCS Digital hiring:                                                   │
# │                                                                                                                 │
# │  *   **Higher Bar:** Significantly higher cut-offs in aptitude and coding compared to TCS Ninja profiles,       │
# │  targeting top performers.                                                                                      │
# │  *   **Niche Skills Focus:** Increased emphasis on practical knowledge and projects in AI/ML, Data Science,     │
# │  Cloud computing, and advanced web development.                                                                 │
# │  *   **Integrated NQT:** Performance in the common NQT gateway often determines eligibility for Digital,        │
# │  Innovator, or Ninja tracks.                                                                                    │
# │  *   **Virtual Process:** The entire hiring process, from tests to interviews, is predominantly virtual,        │
# │  necessitating strong online etiquette and technical setup.                                                     │
# │                                                                                                                 │
# │  ### 5. Your Strategic Prep Plan                                                                                │
# │                                                                                                                 │
# │  Arm yourself with these actionable tips for success:                                                           │
# │                                                                                                                 │
# │  *   **Master DSA & Core CS:** Dedicate substantial time to platforms like LeetCode and HackerRank. Revisit     │
# │  OS, DBMS, OOPs, and Networking fundamentals.                                                                   │
# │  *   **Build Strong Projects:** Develop 2-3 substantial, resume-worthy projects (e.g., full-stack web app, ML   │
# │  model, cloud integration) that showcase your skills.                                                           │
# │  *   **Practice Aptitude Regularly:** Solve quantitative, logical reasoning, and verbal ability questions       │
# │  consistently to improve speed and accuracy.                                                                    │
# │  *   **Mock Interviews & Communication:** Engage in mock technical and HR interviews to articulate              │
# │  problem-solving approaches and project explanations clearly.                                                   │
# │  *   **Stay Updated:** Follow industry trends, learn about new technologies, and understand their real-world    │
# │  applications, especially within TCS's digital offerings.                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Success in TCS Digital is within reach with focused effort and smart preparation. Start early, stay            │
# │  persistent, and transform your potential into a powerful career launchpad. Your future in digital innovation   │
# │  awaits!                                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw="# TCS Digital — Placement Prep Brief\n\nReady to accelerate your career in the cutting-edge world of digital innovation? TCS Digital offers premium roles at the forefront of technology, demanding top talent and a future-forward mindset. This brief is your roadmap to cracking one of India's most sought-after placements.\n\n---\n\n### 1. The Hiring Journey\n\nThe TCS Digital selection process is rigorous, designed to identify future tech leaders:\n\n*   **Online Aptitude Test:** A comprehensive screening via TCS NQT (National Qualifier Test), assessing quantitative aptitude, verbal ability, and logical reasoning.\n*   **Advanced Coding Round:** Clear the aptitude, and you'll face multiple challenging coding problems requiring strong algorithmic and data structure proficiency.\n*   **Technical Interview:** Deep dive into your core computer science fundamentals (OS, DBMS, OOPs, CN), projects, problem-solving approaches, and relevant technical skills.\n*   **Managerial & HR Interview:** Evaluates leadership potential, situational problem-solving, project insights, cultural fit, communication skills, and adaptability.\n\n### 2. Essential Technical Arsenal\n\nTCS Digital roles demand a strong foundation and eagerness to learn emerging tech:\n\n*   **Data Structures & Algorithms (DSA):** Non-negotiable for coding rounds and technical interviews. Master arrays, linked lists, trees, graphs, sorting, searching.\n*   **Cloud Technologies:** Basic understanding of AWS, Azure, or GCP concepts is highly valued for digital transformation projects.\n*   **Programming Languages:** Strong proficiency in at least one modern language (Java, Python, C++, JavaScript) and familiarity with associated frameworks (e.g., Spring Boot, Django).\n*   **Emerging Technologies:** A foundational grasp of AI/ML, IoT, Blockchain, Big Data, or Cybersecurity principles showcases your readiness for digital roles.\n\n### 3. Am I Eligible?\n\nEnsure you meet the basic criteria before applying:\n\n*   **Academic Percentage:** Minimum 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE.\n*   **Degree & Branches:** B.Tech/BE from Computer Science, IT, ECE, EEE, and related engineering disciplines.\n*   **No Active Backlogs:** Must not have any active backlogs at the time of application or during the selection process.\n*   **Academic Gap:** A maximum permissible academic gap of 1-2 years (overall) is generally allowed.\n\n### 4. Key Trends & Expectations\n\nUnderstand the contemporary landscape of TCS Digital hiring:\n\n*   **Higher Bar:** Significantly higher cut-offs in aptitude and coding compared to TCS Ninja profiles, targeting top performers.\n*   **Niche Skills Focus:** Increased emphasis on practical knowledge and projects in AI/ML, Data Science, Cloud computing, and advanced web development.\n*   **Integrated NQT:** Performance in the common NQT gateway often determines eligibility for Digital, Innovator, or Ninja tracks.\n*   **Virtual Process:** The entire hiring process, from tests to interviews, is predominantly virtual, necessitating strong online etiquette and technical setup.\n\n### 5. Your Strategic Prep Plan\n\nArm yourself with these actionable tips for success:\n\n*   **Master DSA & Core CS:** Dedicate substantial time to platforms like LeetCode and HackerRank. Revisit OS, DBMS, OOPs, and Networking fundamentals.\n*   **Build Strong Projects:** Develop 2-3 substantial, resume-worthy projects (e.g., full-stack web app, ML model, cloud integration) that showcase your skills.\n*   **Practice Aptitude Regularly:** Solve quantitative, logical reasoning, and verbal ability questions consistently to improve speed and accuracy.\n*   **Mock Interviews & Communication:** Engage in mock technical and HR interviews to articulate problem-solving approaches and project explanations clearly.\n*   **Stay Updated:** Follow industry trends, learn about new technologies, and understand their real-world applications, especially within TCS's digital offer ...
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 1e6f141d-37ed-431c-9712-5f00f3f24307                                                                       │
# │  Final Output: # TCS Digital — Placement Prep Brief                                                             │
# │                                                                                                                 │
# │  Ready to accelerate your career in the cutting-edge world of digital innovation? TCS Digital offers premium    │
# │  roles at the forefront of technology, demanding top talent and a future-forward mindset. This brief is your    │
# │  roadmap to cracking one of India's most sought-after placements.                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Journey                                                                                      │
# │                                                                                                                 │
# │  The TCS Digital selection process is rigorous, designed to identify future tech leaders:                       │
# │                                                                                                                 │
# │  *   **Online Aptitude Test:** A comprehensive screening via TCS NQT (National Qualifier Test), assessing       │
# │  quantitative aptitude, verbal ability, and logical reasoning.                                                  │
# │  *   **Advanced Coding Round:** Clear the aptitude, and you'll face multiple challenging coding problems        │
# │  requiring strong algorithmic and data structure proficiency.                                                   │
# │  *   **Technical Interview:** Deep dive into your core computer science fundamentals (OS, DBMS, OOPs, CN),      │
# │  projects, problem-solving approaches, and relevant technical skills.                                           │
# │  *   **Managerial & HR Interview:** Evaluates leadership potential, situational problem-solving, project        │
# │  insights, cultural fit, communication skills, and adaptability.                                                │
# │                                                                                                                 │
# │  ### 2. Essential Technical Arsenal                                                                             │
# │                                                                                                                 │
# │  TCS Digital roles demand a strong foundation and eagerness to learn emerging tech:                             │
# │                                                                                                                 │
# │  *   **Data Structures & Algorithms (DSA):** Non-negotiable for coding rounds and technical interviews. Master  │
# │  arrays, linked lists, trees, graphs, sorting, searching.                                                       │
# │  *   **Cloud Technologies:** Basic understanding of AWS, Azure, or GCP concepts is highly valued for digital    │
# │  transformation projects.                                                                                       │
# │  *   **Programming Languages:** Strong proficiency in at least one modern language (Java, Python, C++,          │
# │  JavaScript) and familiarity with associated frameworks (e.g., Spring Boot, Django).                            │
# │  *   **Emerging Technologies:** A foundational grasp of AI/ML, IoT, Blockchain, Big Data, or Cybersecurity      │
# │  principles showcases your readiness for digital roles.                                                         │
# │                                                                                                                 │
# │  ### 3. Am I Eligible?                                                                                          │
# │                                                                                                                 │
# │  Ensure you meet the basic criteria before applying:                                                            │
# │                                                                                                                 │
# │  *   **Academic Percentage:** Minimum 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE.                     │
# │  *   **Degree & Branches:** B.Tech/BE from Computer Science, IT, ECE, EEE, and related engineering              │
# │  disciplines.                                                                                                   │
# │  *   **No Active Backlogs:** Must not have any active backlogs at the time of application or during the         │
# │  selection process.                                                                                             │
# │  *   **Academic Gap:** A maximum permissible academic gap of 1-2 years (overall) is generally allowed.          │
# │                                                                                                                 │
# │  ### 4. Key Trends & Expectations                                                                               │
# │                                                                                                                 │
# │  Understand the contemporary landscape of TCS Digital hiring:                                                   │
# │                                                                                                                 │
# │  *   **Higher Bar:** Significantly higher cut-offs in aptitude and coding compared to TCS Ninja profiles,       │
# │  targeting top performers.                                                                                      │
# │  *   **Niche Skills Focus:** Increased emphasis on practical knowledge and projects in AI/ML, Data Science,     │
# │  Cloud computing, and advanced web development.                                                                 │
# │  *   **Integrated NQT:** Performance in the common NQT gateway often determines eligibility for Digital,        │
# │  Innovator, or Ninja tracks.                                                                                    │
# │  *   **Virtual Process:** The entire hiring process, from tests to interviews, is predominantly virtual,        │
# │  necessitating strong online etiquette and technical setup.                                                     │
# │                                                                                                                 │
# │  ### 5. Your Strategic Prep Plan                                                                                │
# │                                                                                                                 │
# │  Arm yourself with these actionable tips for success:                                                           │
# │                                                                                                                 │
# │  *   **Master DSA & Core CS:** Dedicate substantial time to platforms like LeetCode and HackerRank. Revisit     │
# │  OS, DBMS, OOPs, and Networking fundamentals.                                                                   │
# │  *   **Build Strong Projects:** Develop 2-3 substantial, resume-worthy projects (e.g., full-stack web app, ML   │
# │  model, cloud integration) that showcase your skills.                                                           │
# │  *   **Practice Aptitude Regularly:** Solve quantitative, logical reasoning, and verbal ability questions       │
# │  consistently to improve speed and accuracy.                                                                    │
# │  *   **Mock Interviews & Communication:** Engage in mock technical and HR interviews to articulate              │
# │  problem-solving approaches and project explanations clearly.                                                   │
# │  *   **Stay Updated:** Follow industry trends, learn about new technologies, and understand their real-world    │
# │  applications, especially within TCS's digital offerings.                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Success in TCS Digital is within reach with focused effort and smart preparation. Start early, stay            │
# │  persistent, and transform your potential into a powerful career launchpad. Your future in digital innovation   │
# │  awaits!                                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 3593

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement brief for TCS Digital placement preparation for B.Tech students:
#
# *   **Hiring Process**
#     *   **Online Aptitude Test**: Assesses numerical, verbal, and logical reasoning skills.
#     *   **Coding Round**: Typically 1-2 medium to hard coding problems, often focusing on Data Structures & Algorithms.
#     *   **Technical Interview**: In-depth discussion on projects, core CS subjects (OS, DBMS, OOPS, CN), and problem-solving approach.
#     *   **Managerial Interview (Optional but common)**: Focuses on situational awareness, career goals, and technical leadership potential.
#     *   **HR Interview**: Evaluates communication skills, cultural fit, and discusses compensation/relocation.
#
# *   **Technical Stack**
#     *   **Programming Languages**: Strong proficiency in Java, Python
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career at the forefront of technology? TCS Digital offers coveted roles and a premium package for top engineering talent. Prepare strategically to unlock your potential and secure this exciting opportunity!
#
# ### 1. The Hiring Journey
#
# Navigate the multi-stage selection process with confidence:
#
# *   **Online Aptitude Test**: Sharpen your numerical, verbal, and logical reasoning.
# *   **Coding Round**: Expect 1-2 medium-to-hard problems, heavily focused on Data Structures & Algorithms.
# *   **Technical Interview**: Be ready for in-depth discussions on your projects, core CS subjects (OS, DBMS, OOPS, CN), and problem-solving methodologies.
# *   **Managerial Interview (Common)**: Showcase situational awareness, career aspirations, an

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career at the forefront of technology? TCS Digital offers coveted roles and a premium package for top engineering talent. Prepare strategically to unlock your potential and secure this exciting opportunity!
#
# ### 1. The Hiring Journey
#
# Navigate the multi-stage selection process with confidence:
#
# *   **Online Aptitude Test**: Sharpen your numerical, verbal, and logical reasoning.
# *   **Coding Round**: Expect 1-2 medium-to-hard problems, heavily focused on Data Structures & Algorithms.
# *   **Technical Interview**: Be ready for in-depth discussions on your projects, core CS subjects (OS, DBMS, OOPS, CN), and problem-solving methodologies.
# *   **Managerial Interview (Common)**: Showcase situational awareness, career aspirations, and leadership potential.
# *   **HR Interview**: Focus on communication skills, cultural fit, and discuss compensation details.
#
# ### 2. Your Technical Toolkit
#
# Master these key areas to stand out:
#
# *   **Programming Languages**: Achieve strong proficiency in Java, Python, or C++.
# *   **Data Structures & Algorithms**: Build a rock-solid foundation for efficient problem-solving.
# *   **Core CS Concepts**: Thoroughly understand Operating Systems, Database Management Systems (SQL), and Object-Oriented Programming (OOPs).
# *   **Web Technologies (Relevant Roles)**: Familiarity with HTML, CSS, JavaScript, and frameworks like React/Angular is a plus.
# *   **Cloud & Emerging Tech**: Awareness of AWS, Azure, GCP, AI/ML, or Blockchain demonstrates forward-thinking.
#
# ### 3. Are You Eligible?
#
# Check if you meet the fundamental criteria:
#
# *   **Degree**: All B.E./B.Tech engineering branches are typically eligible.
# *   **Academic Criteria**: Generally requires 60% or 6.0 CGPA throughout 10th, 12th, and graduation.
# *   **Year of Passing**: Open to final-year B.Tech students.
# *   **Backlogs/Gaps**: No active backlogs; maximum 1-year education gap with valid justification.
#
# ### 4. What's Hot Right Now?
